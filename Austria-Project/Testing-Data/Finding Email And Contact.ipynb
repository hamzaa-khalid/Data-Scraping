# %%
# # Sample Script For Traversinf About Page For Websites
aboutlnk = []
for i in range(len(lst_NoContFound)):
    print('------------------------------------------------')
    print(' Link : ', i)
    print('------------------------------------------------')
    driver.get(lst_NoContFound[i])
    time.sleep(2)
    try:
        p1 = driver.find_elements_by_partial_link_text('Über Uns')
        for pp in p1:
            aboutlnk.append(pp.get_attribute('href'))
            
        print('------------------------------------------------')
    except:
        p1 = driver.find_elements_by_partial_link_text('ÜBER UNS')
        for pp in p1:
            aboutlnk.append(pp.get_attribute('href'))
        print('------------------------------------------------')
# Out:
# ------------------------------------------------
#  Link :  0
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
#  Link :  1
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
#  Link :  2
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
#  Link :  3
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
#  Link :  4
# ------------------------------------------------
# ------------------------------------------------
# ------------------------------------------------
#  Link :  5
# ------------------------------------------------
# ------------------------------------------------
# ...

# %%
aboutlnk
# Out:
# ['https://www.youlookperfect.at/pages/label',
#  'https://www.trueboxers.at/pages/about-us',
#  'https://c5rinascimento.at/pages/about-us',
#  'https://cupcakes-wien.at/pages/uber-uns',
#  'https://odonnell.at/pages/about',
#  'https://odonnell.at/pages/about',
#  'https://prooler.at/pages/uber-uns',
#  'https://prooler.at/pages/uber-uns',
#  'https://tierreich-onlineshop.at/pages/uber-uns']

# %% [markdown]
# ### Finding Email & Contact Info From Websites

# %%
#Importing Libraries
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
import re

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--incognito')
driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe',chrome_options=chrome_options)
driver.implicitly_wait(2)
# driver.get('https://enjoy-decor.at')
# Out:
# <ipython-input-6-7ed22ce79fac>:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe',chrome_options=chrome_options)

# %%
# parT = driver.find_elements_by_partial_link_text('Über Uns')
# parT2 = driver.find_element_by_partial_link_text('Kontakt')

# %%
# print(parT2.get_attribute('href'))
# for i in parT:
#     print(i.get_attribute('href'))
# Out:
# https://enjoy-decor.at/pages/kontakt
# https://enjoy-decor.at/pages/uber-uns

# %%
# dt = pd.read_excel('20210512_Domains.xlsx')

# %%
# dt.url[123]
# Out:
# 'https://shop.maryrose.at'

# %% [markdown]
# ### Collecting Email & Phone Numbers If Available On First Page

# %%
dt = pd.read_excel('20210512_Domains.xlsx')
urlFirstPage = list(dt.url)

# %%
len(urlFirstPage)
# Out:
# 891

# %%
import re
# notfoundFirstPage = []
data2 = pd.DataFrame(columns=['Website URL', 'Email', 'Contact'])
data2
# Out:
# Empty DataFrame
# Columns: [Website URL, Email, Contact]
# Index: []

# %%
len(notfoundFirstPage)
# Out:
# 790

# %%
dt = pd.DataFrame(columns=['Links For Not On First Page'])

# %%
dt
# Out:
# Empty DataFrame
# Columns: [Links For Not On First Page]
# Index: []

# %%
for i in notfoundFirstPage:
    dt = dt.append({'Links For Not On First Page': i}, ignore_index=True)

# %%
dt.to_csv('Remaining_Links.csv')

# %%
for i in range(len(notfoundFirstPage)):
    try:
        driver.get(notfoundFirstPage[i])
    except:
        pass
    time.sleep(3)
    driver.implicitly_wait(5)
    # Collecting Page Source
    doc = driver.page_source
    # Collecting Email & Contacy
    time.sleep(3)
    try:
        email = re.search(r'[\w\.-]+@[\w\.-]+.at', doc)
        #number = re.search('\+43+.[0-9]+.[0-9]+.[0-9]*', doc)
        data2 = data2.append({'Website URL': notfoundFirstPage[i], 'Email': email.group(), 'Contact': None}, ignore_index=True)
        emailFirstPage.append(notfoundFirstPage[i])
    except:
        contactNotFirstPage.append(notfoundFirstPage[i])

# %%
len(notfoundFirstPage)
# Out:
# 790

# %%
#Websites Having Contact & Email On First Page
data
# Out:
#                    Website URL                      Email           Contact
# 0       https://enjoy-decor.at        info@enjoy-decor.at    +43 1 9588 268
# 1        https://www.shoepy.at             info@shoepy.at    +436609508777"
# 2     https://bellas-vienna.at      info@bellas-vienna.at  +43 676 6305105<
# 3          https://masken24.at           info@masken24.at      +4314170608
# 4        https://trumerholz.at         shop@trumerholz.at    +43 621729000
# ..                         ...                        ...               ...
# 96         http://vomreiter.at    bestellung@vomreiter.at    +436802257711"
# 97   http://wallmann-textil.at  office@wallmann-textil.at     +43557672126"
# 98      http://xn--shpy-6qa.at             info@shoepy.at    +436609508777"
# 99              http://zabo.at             office@zabo.at  +43 660 6466717<
# 100    http://zaversky-shop.at    office@zaversky-shop.at   +43 3512 82 661
#
# [101 rows x 3 columns]

# %%
# Websites Having Email On First Page
data2
# Out:
#                                 Website URL  \
# 0    https://unverfaelscht-naturkosmetik.at
# 1            https://www.weingut-trummer.at
# 2                   https://shop.interio.at
# 3               https://www.glueckssache.at
# 4                    https://medithappen.at
# ..                                      ...
# 130                       http://westech.at
# 131                   http://wildschuetz.at
# 132             http://xn--zitlossch-87a.at
# 133               http://zeitholzwatches.at
# 134                 http://happydogstore.de
#
#                                    Email Contact
# 0    info@unverfaelscht-naturkosmetik.at    None
# 1          willkommen@weingut-trummer.at    None
# 2                      info@magazin07.at    None
# 3                   info@glueckssache.at    None
# 4                 support@medithappen.at    None
# ..                                   ...     ...
# 130              office@westech-solar.at    None
# ...

# %%
data2.to_csv('OnlyEmail-OnFirstPage.csv', index_label=False)

# %%
data.to_csv('Contact-Email-OnFirstPage.csv', index_label=False)

# %% [markdown]
# ### Traversing To About Page & Finding Email & Contact (If Available)

# %%
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--incognito')
driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe',chrome_options=chrome_options)
driver.implicitly_wait(2)
# Out:
# <ipython-input-18-67ac4d6ba8be>:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver.exe',chrome_options=chrome_options)

# %%
data = pd.read_csv('Remaining_Links.csv')

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#      Links For Not On First Page
# 0             https://myshopp.at
# 1        https://www.spirulix.at
# 2             https://senkels.at
# 3           https://luckyhemp.at
# 4  https://www.thurzo-juwelen.at

# %%
lst = list(data['Links For Not On First Page'])

# %%
len(lst)
# Out:
# 790

# %%
driver.get(lst[18])
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-24-6388722179d1> in <module>
# ----> 1 driver.get(lst[18])
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ...

# %%
# Main Code To Run
lst2 = []
lst3 = []
for i in range(len(lst)):
    driver.get(lst[i])
    time.sleep(2)
    try:
        p1 = driver.find_elements_by_partial_link_text('Über Uns')
        p2 = driver.find_element_by_partial_link_text('Kontakt')
    except:
        p1 = driver.find_elements_by_partial_link_text('ÜBER UNS')
        p2 = driver.find_element_by_partial_link_text('KONTAKT')

# %%
# parT = driver.find_elements_by_partial_link_text('Über Uns')
# parT = driver.find_elements_by_partial_link_text('ÜBER UNS')
# parT2 = driver.find_element_by_partial_link_text('Kontakt')
# parT2 = driver.find_element_by_partial_link_text('KONTAKT')

# %%
lst_Cont = []
lst_NoContFound = []
for i in range(len(lst)):
    print('------------------------------------------------')
    print(' Link : ', i)
    try:
        driver.get(lst[i])
        time.sleep(2)
        try:
            try:
                time.sleep(1)
                p2 = driver.find_element_by_partial_link_text('Kontakt')
                lst_Cont.append(p2.get_attribute('href'))
                time.sleep(1)
                print('------------------------------------------------')
            except:
                time.sleep(1)
                p2 = driver.find_element_by_partial_link_text('KONTAKT')
                lst_Cont.append(p2.get_attribute('href'))
                time.sleep(1)
                print('------------------------------------------------')
        except:
            lst_NoContFound.append(lst[i])
    except:
        pass
# Out:
# ------------------------------------------------
#  Link :  0
# ------------------------------------------------
# ------------------------------------------------
#  Link :  1
# ------------------------------------------------
# ------------------------------------------------
#  Link :  2
# ------------------------------------------------
# ------------------------------------------------
#  Link :  3
# ------------------------------------------------
# ------------------------------------------------
#  Link :  4
# ------------------------------------------------
# ------------------------------------------------
#  Link :  5
# ------------------------------------------------
# ------------------------------------------------
#  Link :  6
# ------------------------------------------------
#  Link :  7
# ------------------------------------------------
#  Link :  8
# ------------------------------------------------
# ------------------------------------------------
#  Link :  9
# ...

# %%
dt = pd.DataFrame(columns=['ContactPage'])
for i in lst_Cont:
    dt = dt.append({'ContactPage': i}, ignore_index= True)

# %%
dt.to_csv('ContactPageLinks.csv')

# %%
lst_Cont
# Out:
# ['https://www.bikelicht.at/pages/kontakt',
#  'https://www.spirulix.at/pages/kontakt',
#  'https://senkels.at/pages/contact-us',
#  'https://luckyhemp.de/pages/kontakt',
#  'https://www.thurzo-juwelen.at/pages/kontakt',
#  'https://brotkost.at/pages/kontakt',
#  'https://citybiker.at/pages/kontakt',
#  'https://goodrun.at/pages/kontakt',
#  'https://www.dantendorfer.at/pages/kontakt',
#  'https://unverfaelscht-naturkosmetik.at/pages/kontakt',
#  'https://www.weingut-trummer.at/pages/kontakt',
#  'https://shop.interio.at/pages/kontakt',
#  'https://dieklemme.at/pages/kontakt',
#  'mailto:info@glueckssache.at',
#  'https://medithappen.at/support/']

# %%
p2 = driver.find_element_by_partial_link_text('Kontakt')
print(p2.get_attribute('href'))
# Out:
# https://shop.falstaff.at/pages/kontakt

# %%
lst_NoContFound
# Out:
# ['https://www.hikezeit.at',
#  'https://www.bakker.at',
#  'https://fitindentag.at',
#  'https://www.sportnahrung.co.at',
#  'https://hygiene-austria.at',
#  'https://royal-donuts.at',
#  'https://shortup.at',
#  'https://der-apotheker.at',
#  'https://shop.falstaff.at',
#  'http://pony-b.at',
#  'https://heysunshine.at',
#  'https://myfinejewellery.at',
#  'https://sodastream.at',
#  'https://www.hamtil.at',
#  'https://store.y.at',
#  'https://keego.at',
#  'https://www.nu3.at',
#  'https://www.mkstore.at',
#  'https://warmy.at',
#  'https://www.smarthans.at',
#  'https://www.gemmazone.at',
#  'https://shop.trend.at',
#  'https://suessmund.at',
#  'https://syrup.at',
#  'https://www.koffeinschmiede.at',
#  'https://booboo.at',
#  'https://zweipunkt.at',
#  'https://mypua.at',
#  'https://it-welt24.at',
#  'https://impalacosmetics.at',
#  'https://www.youlookperfect.at',
#  'https://stokedandwokeclothing.at',
#  'https://bigdeal4you.at',
#  'https://brainsmart.at',
# ...

# %%
lst_NoContFound = ['https://www.hikezeit.at',
 'https://www.bakker.at',
 'https://fitindentag.at',
 'https://www.sportnahrung.co.at',
 'https://hygiene-austria.at',
 'https://royal-donuts.at',
 'https://shortup.at',
 'https://der-apotheker.at',
 'https://shop.falstaff.at',
 'http://pony-b.at',
 'https://heysunshine.at',
 'https://myfinejewellery.at',
 'https://sodastream.at',
 'https://www.hamtil.at',
 'https://store.y.at',
 'https://keego.at',
 'https://www.nu3.at',
 'https://www.mkstore.at',
 'https://warmy.at',
 'https://www.smarthans.at',
 'https://www.gemmazone.at',
 'https://shop.trend.at',
 'https://suessmund.at',
 'https://syrup.at',
 'https://www.koffeinschmiede.at',
 'https://booboo.at',
 'https://zweipunkt.at',
 'https://mypua.at',
 'https://it-welt24.at',
 'https://impalacosmetics.at',
 'https://www.youlookperfect.at',
 'https://stokedandwokeclothing.at',
 'https://bigdeal4you.at',
 'https://brainsmart.at',
 'https://www.fabstore.at',
 'https://shop.maryrose.at',
 'https://wipercutter.at',
 'https://drmarylove.at',
 'https://shop.mysommelier.at',
 'https://ninawa.at',
 'https://www.myokee.at',
 'https://privatec.at',
 'https://flohmarkt.derfloh.at',
 'https://puramed.at',
 'https://shop.weinwurms.at',
 'https://www.health-solution.at',
 'https://littlefairytalevienna.at',
 'https://www.trueboxers.at',
 'https://medinaut.at',
 'https://modefabrik-austria.at',
 'https://tichlo.at',
 'https://www.glueckskind-shop.at',
 'http://zippo.at',
 'https://www.elivrosenkranz.at',
 'https://shop.autorevue.at',
 'https://www.bayama.at',
 'https://www.balkanstreetwear.at',
 'https://www.warrior.co.at',
 'https://funkymasks.at',
 'https://mujideluxe.at',
 'https://www.ferrocom-sitwell.at',
 'https://shop.meineck.at',
 'https://www.meinduftspender.at',
 'https://shirthelden.at',
 'https://designforyou.at',
 'https://buch.stefan-magnet.at',
 'https://hangtags.at',
 'https://b2b.koffeinschmiede.at',
 'https://restboden.at',
 'https://unqe.at',
 'https://shop.volkshilfe-wien.at',
 'https://laendleprinteria.at',
 'https://www.urbanara.at',
 'https://jujudesign.at',
 'https://shop.metos.at',
 'https://www.mybodyoase.at',
 'https://ysdt.co.at',
 'https://cozycave.at',
 'https://evomia.at',
 'https://www.h2o-diffuser.at',
 'https://happy-deals.at',
 'https://hierumseck.at',
 'https://homeofficeshop.at',
 'https://wunderbirne.at',
 'https://attilus.at',
 'https://easy-case.at',
 'https://eiskratzer.at',
 'https://eshop.gerstner-konditorei.at',
 'https://www.jennysparfumeriewelt.at',
 'https://sockenschuhe.at',
 'https://shop.lisa-alm.at',
 'https://veganpower.at',
 'https://www.bunte-masken.at',
 'https://www.hadewoo.at',
 'https://lilias-stroller.at',
 'https://www.skiwater.at',
 'https://trittmich.at',
 'https://weedstuff.at',
 'https://bganic.at',
 'https://www.cbd-wiesn.at',
 'https://darkroomsnow.at',
 'https://shop.entbrannt-wodka.at',
 'http://faceslim.at',
 'https://www.freches-katzerl.at',
 'https://hair-away.at',
 'https://hybridbrush.at',
 'https://kleidermachenleute.at',
 'https://www.lolika.at',
 'https://shop.mastersofmerch.at',
 'https://meistertonikum.at',
 'https://more-sleep.at',
 'https://onlinesim.at',
 'https://www.rotweinelang.at',
 'https://sparklebonsai.at',
 'https://shop.sumup.at',
 'https://www.swano-tex-shop.at',
 'https://vapeland.at',
 'https://waldlandshop.at',
 'https://shop.warda.at',
 'https://wienerblut.at',
 'https://bakker-at.myshopify.com',
 'https://jujudesignwien.myshopify.com',
 'https://luvett-at.myshopify.com',
 'https://trittdrauf.myshopify.com',
 'https://werta-kuche-haushalt.myshopify.com',
 'https://deal4you.at',
 'https://shop.marschpat.at',
 'https://www.pfotenlove.at',
 'https://smart-dry.at',
 'https://surpriseme.at',
 'https://thewatchers.at',
 'https://tierresort.at',
 'https://shop.trendinggoods.at',
 'https://b-bagstore.at',
 'https://bowllife.at',
 'https://dreambodies.at',
 'https://www.kawaiikatzen.at',
 'https://menzo.at',
 'https://staylaxed.at',
 'http://123homeoffice.at',
 'http://3d-druckshop.at',
 'http://3dekolichter.at',
 'http://5log.at',
 'http://aeronics.at',
 'http://agmen.at',
 'http://allfordogs.at',
 'http://alloutgeek.at',
 'http://alpenstyler.at',
 'http://amepure.at',
 'http://andiwojta.at',
 'http://andsimple.at',
 'http://animalclean.at',
 'http://anticovid.at',
 'http://apoauhof.at',
 'http://atriumdeutschlandsberg.at',
 'http://austix.at',
 'http://aykem.at',
 'http://b15.at',
 'http://babylein.at',
 'http://babyunterwegs.at',
 'http://backmatte.at',
 'http://backrelief.at',
 'http://badinform.at',
 'http://banino-alpenjuwel.at',
 'http://baskan.at',
 'http://basply.at',
 'http://batimat-shop.at',
 'http://bbq-brothers.at',
 'http://bcase.at',
 'http://beanie.at',
 'http://bikefabrik.at',
 'http://bikesly.at',
 'http://boses.at',
 'http://brevie.at',
 'http://bruda.at',
 'http://bruncho.at',
 'http://brunpht.at',
 'http://brushly.at',
 'http://burgeratelier-salzburg.at',
 'http://c5rinascimento.at',
 'http://cannaworld.at',
 'http://clean-kitchen.at',
 'http://cleankitchen.at',
 'http://clear-face.at',
 'http://clearchoice.at',
 'http://clever-clip.at',
 'http://clickswim.at',
 'http://comfybear.at',
 'http://cornelius-shop.at',
 'http://crazy-mask.at',
 'http://cupcakes-wien.at',
 'http://dekogeil.at',
 'http://didierlab.at',
 'http://diefruhwirths.at',
 'http://diehaushaltshelfer.at',
 'http://dogs-professional.at',
 'http://dream-light.at',
 'http://dreamily.at',
 'http://drink-mana.at',
 'http://e-bikes.at',
 'http://easy-kitchen.at',
 'http://easycharge.at',
 'http://elijah-shop.at',
 'http://enjjoy.at',
 'http://enjoyhome.at',
 'http://erlebniswerkstattl-shop.at',
 'http://famd.at',
 'http://fantasy-jungle.at',
 'http://fashion-breakfast.at',
 'http://fixflake.at',
 'http://flexitowel.at',
 'http://fliegerzimmer.at',
 'http://floradaniela.at',
 'http://flored.at',
 'http://flowersome.at',
 'http://flowflip.at',
 'http://flugball.at',
 'http://found-scan.at',
 'http://gadget2u.at',
 'http://galaxielicht.at',
 'http://galaxielichter.at',
 'http://galerierudolfleeb.at',
 'http://gesundheit-zum-mitnehmen.at',
 'http://getraenke-abverkauf.at',
 'http://glaciergames.at',
 'http://glowtree.at',
 'http://go-bodycare.at',
 'http://goodwatch.at',
 'http://goppioncaffe.at',
 'http://graetzlheldin.at',
 'http://grandseigneur.at',
 'http://greatdeals.at',
 'http://groomee.at',
 'http://groxy.at',
 'http://handy-wie-neu.at',
 'http://happymug.at',
 'http://happypetsstore.at',
 'http://happypup.at',
 'http://hausundhofshop.at',
 'http://hbdeadsea.at',
 'http://hellobabes.at',
 'http://herbalair.at',
 'http://herzgemacht.at',
 'http://heyrussell.at',
 'http://hoits.at',
 'http://holzmodelle.at',
 'http://htl-shop.at',
 'http://icelo-tech.at',
 'http://icyair.at',
 'http://infuehr.at',
 'http://infusetea.at',
 'http://ittner.at',
 'http://jahla.at',
 'http://jellylight.at',
 'http://kariakoo.at',
 'http://karvetti.at',
 'http://kattash.at',
 'http://katzen-welt.at',
 'http://keepin.at',
 'http://khg-das-spiel.at',
 'http://kingcredible.at',
 'http://kitchenstar.at',
 'http://kleineraupe.at',
 'http://kochkistl.at',
 'http://koerperwaechter.at',
 'http://ladeloesungen.at',
 'http://leatherly.at',
 'http://lepetitchou.at',
 'http://lesnereides.at',
 'http://leycon.at',
 'http://livity.at',
 'http://locobike.at',
 'http://lokal-frisch.at',
 'http://loveyourpet.at',
 'http://luftreinigung24.at',
 'http://luvett.at',
 'http://luvpets.at',
 'http://maasmoebel.at',
 'http://magazin-romanesc.at',
 'http://magic-brush.at',
 'http://magicpen.at',
 'http://magne-table.at',
 'http://magnetable.at',
 'http://mahima.at',
 'http://malawico.at',
 'http://malycape.at',
 'http://manuelessldesign.at',
 'http://maskulo.at',
 'http://meacoffee.at',
 'http://medpointshop.at',
 'http://megatool.at',
 'http://mevido-jewelry.at',
 'http://miketea.at',
 'http://mikiliki.at',
 'http://mikls-erdbeereck.at',
 'http://misadu.at',
 'http://misterbaer.at',
 'http://mktcars.at',
 'http://mmholzdesign.at',
 'http://modernwatch.at',
 'http://mokete.at',
 'http://morotai.at',
 'http://msh-schutzbekleidung.at',
 'http://msjewelry.at',
 'http://multiflextools.at',
 'http://muse-design.at',
 'http://my-shiatsu.at',
 'http://myolive.at',
 'http://mypracticalhome.at',
 'http://mysommelier.at',
 'http://mystarcity.at',
 'http://nailology.at',
 'http://naturalsolutions.at',
 'http://naturfasten.at',
 'http://neonly.at',
 'http://netone.at',
 'http://neverseenbefore.at',
 'http://nftm.at',
 'http://ninelife.at',
 'http://ninthavenue.at',
 'http://norvine.at',
 'http://novacolor.at',
 'http://nudelhoiz.at',
 'http://nuffinz.at',
 'http://o-brians.at',
 'http://oceanlamp.at',
 'http://octomotion.at',
 'http://odonnell.at',
 'http://ohbaby.at',
 'http://olpro.at',
 'http://onlineshop24.at',
 'http://only-4-pets.at',
 'http://orthopedix.at',
 'http://osma-nowik.at',
 'http://osomo.at',
 'http://ottoc.at',
 'http://oxyd.at',
 'http://pandemickitchen.at',
 'http://panux.at',
 'http://partywerk.at',
 'http://pastarro-schlafen.at',
 'http://petipeti.at',
 'http://powerbands.at',
 'http://practically4you.at',
 'http://preppersflames-krisenvorsorge.at',
 'http://prettyface.at',
 'http://prooler.at',
 'http://puripro.at',
 'http://pushfit.at',
 'http://quick-play.at',
 'http://quickheat.at',
 'http://quinns.at',
 'http://r4f-alpakas.at',
 'http://radaubruder.at',
 'http://regio-masks.at',
 'http://reil-cosmetics.at',
 'http://reinesgspuer.at',
 'http://rettetdiekoalas.at',
 'http://rewardclub.at',
 'http://roam-bracelets.at',
 'http://rollinart.at',
 'http://salecart.at',
 'http://sanbag.at',
 'http://santas-smile.at',
 'http://santoria.at',
 'http://schalleritin.at',
 'http://schattenlichter.at',
 'http://schickemaske.at',
 'http://schlaf-gut-baby.at',
 'http://schmuck365.at',
 'http://schneeweiss-rosenrot.at',
 'http://schnullerdirekt.at',
 'http://schrabacher.at',
 'http://schuli.at',
 'http://screwmate.at',
 'http://shapebody.at',
 'http://she-is.at',
 'http://shine-bright.at',
 'http://shop-oliver-sven-simon.at',
 'http://shop4u.at',
 'http://shophero.at',
 'http://shoptastisch24.at',
 'http://simplygreens.at',
 'http://smartfoil.at',
 'http://spicysoul.at',
 'http://splashpad.at',
 'http://statemnt.at',
 'http://sternenprinz.at',
 'http://suena.at',
 'http://summergirl.at',
 'http://super-toy.at',
 'http://survivedcorona.at',
 'http://tannymaxx.at',
 'http://taschenparadies.at',
 'http://tiergeschenke.at',
 'http://tierreich-onlineshop.at',
 'http://tirolmojo.at',
 'http://tirolox.at',
 'http://tisch-hockey-brettspiel.at',
 'http://tischtennisshop.at',
 'http://tophype.at',
 'http://topmasken.at',
 'http://toptrendy.at',
 'http://trachten-masken.at',
 'http://ungerade.at',
 'http://unpockbar.at',
 'http://uphands.at',
 'http://upperhand.at',
 'http://upsticker.at',
 'http://uwear.at',
 'http://vacuumxtreme.at',
 'http://vasc.at',
 'http://vean.at',
 'http://vegamino.at',
 'http://verdero.at',
 'http://voom.at',
 'http://vrechfoods.at',
 'http://wasser-stoff.at',
 'http://waszusagenist.at',
 'http://watershoes.at',
 'http://weinimkorb.at',
 'http://werta.at',
 'http://whatineed.at',
 'http://wicks.at',
 'http://wienbleibtwien.at',
 'http://wienerschurken.at',
 'http://wienett.at',
 'http://wildschuetz.at',
 'http://wm-beauty.at',
 'http://woess-designeroutlet.at',
 'http://wonderjeans.at',
 'http://xn--frequenzerhhung-jtb.at',
 'http://xn--schalldmpfer-mcb.at',
 'http://xn--zitlossch-87a.at',
 'http://xyfindit.at',
 'http://yourdailylife.at',
 'http://yourfavorite.at',
 'http://aphrodite-trainer.com',
 'http://cbd-feelgood.com',
 'http://doggodna.com',
 'http://hausruck-genuss.com']

# %%
len(lst_NoContFound)
# Out:
# 441

# %% [markdown]
# ## Finding Contact/Email From Contact Pages of Websites

# %%
df = pd.read_csv('ContactPageLinks.csv')

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#                                    ContactPage
# 0       https://www.bikelicht.at/pages/kontakt
# 1        https://www.spirulix.at/pages/kontakt
# 2          https://senkels.at/pages/contact-us
# 3           https://luckyhemp.de/pages/kontakt
# 4  https://www.thurzo-juwelen.at/pages/kontakt

# %%
len(df)
# Out:
# 328

# %%
df2 = pd.DataFrame(columns=['Website URL', 'Email', 'Contact'])

# %%
df2
# Out:
# Empty DataFrame
# Columns: [Website URL, Email, Contact]
# Index: []

# %%
for i in range(len(df)):
    try:
        driver.get(df['ContactPage'][i])
    except:
        pass
    time.sleep(3)
    driver.implicitly_wait(5)
    # Collecting Page Source
    doc = driver.page_source
    # Collecting Email & Contacy
    time.sleep(2)
    try:
        try:
            email = re.search(r'[\w\.-]+@[\w\.-]+.at', doc)
            ee = email.group()
        except:
            ee = None
        try:
            number = re.search('\+43+.[0-9]+.[0-9]+.[0-9]*', doc)
            nn = number.group()
        except:
            nn = None
    except:
        pass
    df2 = df2.append({'Website URL': df['ContactPage'][i], 'Email': ee, 'Contact': nn}, ignore_index=True)

# %%
df2.to_csv('328new.csv')

# %%
# Collecting Page Source
doc = driver.page_source
# Collecting Email & Contacy
time.sleep(2)
email = re.search(r'[\w\.-]+@[\w\.-]+.at', doc)
ee = email.group()
print(ee)
# Out:
# wien7@citybiker.at

# %%
number = re.search('\+43+.[0-9]+.[0-9]+.[0-9]*', doc)
nn = number.group()
print(nn)
# Out:
# +4315221902"

# %%
import pandas as pd
df = pd.read_csv('328new.csv')
del df['Unnamed: 0']

# %%
df
# Out:
#                                      Website URL                  Email  \
# 0         https://www.bikelicht.at/pages/kontakt      info@bikelicht.at
# 1          https://www.spirulix.at/pages/kontakt      hallo@spirulix.at
# 2            https://senkels.at/pages/contact-us        info@senkels.at
# 3             https://luckyhemp.de/pages/kontakt                    NaN
# 4    https://www.thurzo-juwelen.at/pages/kontakt                    NaN
# ..                                           ...                    ...
# 323    https://www.spruchketten.at/pages/kontakt                    NaN
# 324    https://www.spruchketten.at/pages/kontakt                    NaN
# 325    https://www.spruchketten.at/pages/kontakt                    NaN
# 326   https://www.hundeliebling.at/pages/kontakt  info@hundeliebling.at
# 327         https://royalkitten.at/pages/kontakt                    NaN
#
#             Contact
# 0               NaN
# 1    +436642475741"
# 2    +436764925158"
# ...
